# %% [markdown]
# ## IPL Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('IPL.csv')
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
print(f"The Row is {df.shape[0]} and Column is {df.shape[1]}")
# Out:
# The Row is 74 and Column is 20

# %%
df.isnull()
# Out:
#     match_id   date  venue  team1  team2  stage  toss_winner  toss_decision  \
# 0      False  False  False  False  False  False        False          False
# 1      False  False  False  False  False  False        False          False
# 2      False  False  False  False  False  False        False          False
# 3      False  False  False  False  False  False        False          False
# 4      False  False  False  False  False  False        False          False
# ..       ...    ...    ...    ...    ...    ...          ...            ...
# 69     False  False  False  False  False  False        False          False
# 70     False  False  False  False  False  False        False          False
# 71     False  False  False  False  False  False        False          False
# 72     False  False  False  False  False  False        False          False
# 73     False  False  False  False  False  False        False          False
#
# ...

# %% [markdown]
# 1. find which team won most maches

# %%
mywinner = df['match_winner'].value_counts()
mywinner
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Delhi         7
# Punjab        7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
sns.barplot(x=mywinner.values,y=mywinner.index,palette='magma')
plt.title("matches winner bars")
# Out:
# Text(0.5, 1.0, 'matches winner bars')

# %% [markdown]
# 2. Toss decision trend

# %%
toss_d=df['toss_decision'].value_counts()

# %%
#plt.subplot(1,2,1)
x=toss_d.index
y=toss_d.values
plt.bar(x,y)
plt.show()
#plt.subplot(1,2,2)
#sns.barplot(x,y,palette='magma')

# %%
sns.barplot(x=toss_d.index,y=toss_d.values,palette='magma')
plt.title("The Toss D Trend")
# Out:
# Text(0.5, 1.0, 'The Toss D Trend')

# %%
sns.countplot(x=df["toss_decision"],palette="viridis")
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# 3. Toss Winner V/S Match winner

# %%
#a=df["toss_winner"].value_counts()
#b=df["match_winner"].value_counts()
#plt.bar(x=a.index,y=a.values,color="r",width=5)
#plt.bar(x=b.index,y=b.values,color="g",width=5)
#pl.show()

# %%
count = df[df['toss_winner'] == df['match_winner']]['match_id'].count()        #🛑here df[df['toss_winner'] == df['match_winner']] is filtering the data where this condition satisfy these data comes together and in these data we accesss the match id column and then count the rows how many that match id who satisfy this condition
percentage=(count*100)/df.shape[0]
print(f"The percentage to win toss and win the match is {percentage.round(3)} %")
# Out:
# The percentage to win toss and win the match is 48.649 %

# %% [markdown]
# 4. How the match win

# %%
sns.countplot(x=df['match_winner'],palette='magma')
# Out:
# <Axes: xlabel='match_winner', ylabel='count'>

# %%
sns.countplot(x=df['won_by'],palette='magma')
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %% [markdown]
# 5. trend of player of the matches

# %%
sns.countplot(y=df['player_of_the_match'],palette='magma',width=0.8)
# Out:
# <Axes: xlabel='count', ylabel='player_of_the_match'>

# %%
counts=df['player_of_the_match'].value_counts().head(20)
counts
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Umesh Yadav          2
# Quinton de Kock      2
# David Miller         2
# Umran Malik          2
# K L Rahul            2
# Rahul Tripathi       2
# Hardik Pandya        2
# Jasprit Bumrah       2
# Shubman Gill         2
# Yuzvendra Chahal     2
# Wanindu Hasaranga    2
# Avesh Khan           2
# Dinesh Karthik       2
# Virat Kohli          1
# Rinku Singh          1
# Kagiso Rabada        1
# Harshal Patel        1
# David Warner         1
# Name: count, dtype: int64

# %%
sns.barplot(y=counts.index,x=counts.values,palette='viridis')
# Out:
# <Axes: ylabel='player_of_the_match'>

# %% [markdown]
# 6. 2 Top Scores

# %%
myscore=df['top_scorer'].value_counts().head(2)
sns.barplot(y=myscore.index,x=myscore.values,palette='magma')
plt.title(" Two Top Scorers")
# Out:
# Text(0.5, 1.0, ' Two Top Scorers')

# %% [markdown]
# 7. 10 Best Bowling Figures

# %%
count=df['best_bowling'].value_counts().head(10)
sns.barplot(y=count.index,x=count.values)
# Out:
# <Axes: ylabel='best_bowling'>

# %%
df["highest_wickets"]=df['best_bowling_figure'].apply(lambda x : x.split('--')[0])
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df["highest_wickets"] = df["highest_wickets"].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# 8. Venue Analysis

# %%
vcount = df['venue'].value_counts()
sns.barplot(y=vcount.index,x=vcount.values,palette='magma')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# # Custom Questions

# %%
df.head(20)
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6          7  March 31,2022                     Brabourne Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 8          9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9         10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
# 10        11   April 3,2022                     Brabourne Stadium, Mumbai
# 11        12   April 4,2022            Dr DY Patil Sports Academy, Mumbai
# ...

# %% [markdown]
# Q.1 who won the highest margin by runs?

# %%
df[df['won_by']=="Runs"].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# Q.2 which player had the highest individuals score

# %%
df[df['highscore']==df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q.3 which bowler had the best bowling figure

# %%
df[df['highest_wickets']== df['highest_wickets'].max()][['highscore','best_bowling_figure']]
# Out:
#     highscore best_bowling_figure
# 29        103               5--40
# 39         68               5--25
# 53         73               5--18
# 55         51               5--10
